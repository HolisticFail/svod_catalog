# %%
#library needed
import pandas as pd
import matplotlib as mlp
import seaborn as sns

# %%
#netflix csv
df1 = pd.read_csv('netflixData.csv')
df1 = df1.rename(columns={' country':'country'})
df1.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genre', 'description'],
#       dtype='object')

# %%
#delete column not needed: show_id, director, cast, rating, description
df_netflix = df1[['type', 'title', 'country', 'date_added', 'release_year','duration', 'genre']].copy()
df_netflix.fillna("no_value", inplace = True)
df_netflix.head(15)
# Out:
#        type                          title                country date_added  \
# 0   TV Show                       (Un)Well          United States   no_value
# 1     Movie                         #Alive            South Korea   8-Sep-20
# 2     Movie  #AnneFrank - Parallel Stories                  Italy   1-Jul-20
# 3   TV Show                       #blackAF          United States   no_value
# 4     Movie               #cats_the_mewvie                 Canada   5-Feb-20
# 5     Movie              #FriendButMarried              Indonesia  21-May-20
# 6     Movie            #FriendButMarried 2              Indonesia  28-Jun-20
# 7     Movie                   #realityhigh          United States   8-Sep-17
# 8     Movie                      #Rucker50          United States   1-Dec-16
# 9     Movie                        #Selfie                Romania  21-Jun-21
# 10    Movie                     #Selfie 69                Romania  21-Jun-21
# ...

# %%
#df_netflix type repartition
sns.histplot(data=df_netflix, x="type")
# Out:
# <AxesSubplot: xlabel='type', ylabel='Count'>

# %%
#df_netflix country repartition
print(df_netflix.country.unique())
print(df_netflix.country.value_counts())
# Out:
# ['United States' 'South Korea' 'Italy' 'Canada' 'Indonesia' 'Romania'
#  'South Africa, Nigeria' 'France' 'Portugal, Spain' 'India' 'Egypt'
#  'Spain' 'Poland, United States' 'Mexico' 'no_value' 'Thailand' 'Turkey'
#  'United Kingdom' 'Norway, Iceland, United States' 'Singapore'
#  'United States, France, Serbia' 'Germany' 'Brazil' 'Poland' 'Japan'
#  'Kenya' 'Nigeria' 'Australia' 'Australia, United States'
#  'Mexico, United States' 'China, Hong Kong' 'Taiwan'
#  'France, South Korea, Japan' 'United Kingdom, United States' 'Denmark'
#  'Hong Kong' 'United States, China' 'France, Netherlands, Singapore'
#  'Argentina' 'China' 'Philippines' 'United Kingdom, Spain, United States'
#  'Netherlands' 'United Kingdom, Hong Kong'
#  'United Kingdom, France, Belgium, Ireland, United States'
#  'Argentina, Brazil, France, Poland, Germany, Denmark'
#  'United States, Mexico' 'Uruguay, Argentina, Spain'
#  'United States, Canada' 'Singapore, France' 'Pakistan'
# ...

# %%
df_netflix.country = df_netflix.country.astype(str)
df_netflix.country.info()


#df_netflix["main_country"] = df_netflix['country'].str.split(',',1).str
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8807 entries, 0 to 8806
# Series name: country
# Non-Null Count  Dtype
# --------------  -----
# 8807 non-null   object
# dtypes: object(1)
# memory usage: 68.9+ KB

# %%
#df_netflix duration repartition
print(df_netflix.duration.unique())
display(df_netflix.duration.value_counts())
# Out:
# ['1 Season' '99 min' '95 min' '90 min' '102 min' '104 min' '56 min'
#  '125 min' '119 min' '87 min' '97 min' '109 min' '44 min' '101 min'
#  '89 min' '4 Seasons' '3 Seasons' '84 min' '124 min' '114 min' '130 min'
#  '103 min' '143 min' '107 min' '158 min' '144 min' '78 min' '140 min'
#  '135 min' '117 min' '92 min' '164 min' '93 min' '91 min' '116 min'
#  '2 Seasons' '105 min' '120 min' '96 min' '75 min' '115 min' '129 min'
#  '80 min' '77 min' '148 min' '123 min' '121 min' '131 min' '28 min'
#  '122 min' '94 min' '85 min' '22 min' '86 min' '137 min' '68 min' '29 min'
#  '168 min' '21 min' '59 min' '113 min' '20 min' '108 min' '111 min'
#  '110 min' '100 min' '83 min' '26 min' '156 min' '30 min' '57 min'
#  '82 min' '98 min' '133 min' '154 min' '146 min' '136 min' '106 min'
#  '88 min' '52 min' '24 min' '74 min' '63 min' '151 min' '38 min' '25 min'
#  '174 min' '60 min' '81 min' '150 min' '142 min' '162 min' '49 min'
# ...

# %%
dic_time = {'99 min': '< 100min' ,'95 min': '< 100min' ,'90 min': '< 100min' ,'102 min': '< 200min' , 
            '104 min': '< 200min' ,'56 min': '< 60min' ,'125 min': '< 200min' ,'119 min': '< 200min' ,
            '87 min': '< 100min' ,'97 min': '< 100min' ,'109 min': '< 200min' ,'44 min': '< 60min' ,
            '101 min': '< 200min' ,'89 min': '< 100min' ,'84 min': '< 100min' ,'124 min': '< 200min' ,
            '114 min': '< 200min' ,'130 min': '< 200min' ,'103 min': '< 200min' ,'143 min': '< 200min' ,
            '107 min': '< 200min' ,'158 min': '< 200min' ,'144 min': '< 200min' ,'78 min': '< 100min' ,
            '140 min': '< 200min' ,'135 min': '< 200min' ,'117 min': '< 200min' ,'92 min': '< 100min' ,
            '164 min': '< 200min' ,'93 min': '< 100min' ,'91 min': '< 100min' ,'116 min': '< 200min' ,
            '105 min': '< 200min' ,'120 min': '< 200min' ,'96 min': '< 100min' ,'75 min': '< 100min' ,
            '115 min': '< 200min' ,'129 min': '< 200min' ,'80 min': '< 100min' ,'77 min': '< 100min' ,
            '148 min': '< 200min' ,'123 min': '< 200min' ,'121 min': '< 200min' ,'131 min': '< 200min' ,
            '28 min': '< 60min' ,'122 min': '< 200min' ,'94 min': '< 100min' ,'85 min': '< 100min' ,
            '22 min': '< 60min' ,'86 min': '< 100min' ,'137 min': '< 200min' ,'68 min': '< 100min' ,
            '29 min': '< 60min' ,'168 min': '< 200min' ,'21 min': '< 60min' ,'59 min': '< 60min' ,
            '113 min': '< 200min' ,'20 min': '< 60min' ,'108 min': '< 100min' ,'111 min': '< 200min' ,
            '110 min': '< 200min' ,'100 min': '< 100min' ,'83 min': '< 100min','26 min': '< 60min' ,
            '26 min': '< 60min' ,'156 min': '< 200min' ,'30 min': '< 60min' ,'57 min': '< 60min' ,
            '82 min': '< 100min' ,'98 min': '< 100min' ,'133 min': '< 100min' ,'154 min': '< 200min' ,
            '146 min': '< 200min' ,'136 min': '< 200min' ,'106 min': '< 200min' ,'88 min': '< 100min' ,
            '52 min': '< 60min' ,'24 min': '< 60min' ,'74 min': '< 100min' ,'63 min': '< 100min' ,
            '151 min': '< 200min' ,'38 min': '< 60min' ,'25 min': '< 60min' ,'174 min': '< 200min' ,
            '60 min': '< 60min' ,'81 min': '< 100min' ,'150 min': '< 200min' ,'142 min': '< 200min' ,
            '162 min': '< 200min' ,'49 min': '< 60min' ,'54 min': '< 60min' ,'51 min': '< 60min' ,
            '214 min': '> 200min' ,'69 min': '< 100min' ,'64 min': '< 100min' ,'147 min': '< 200min' ,
            '42 min': '< 60min' ,'79 min': '< 100min' ,'40 min': '< 60min' ,'112 min': '< 200min' ,'10 min':'< 60min',
            '30 min': '< 60min' ,'126 min': '< 200min' ,'72 min': '< 100min' ,'127 min': '< 200min' ,
            '124 min': '< 200min' ,'61 min': '< 100min' ,'71 min': '< 100min' ,'70 min': '< 100min' ,
            '160 min': '< 200min' ,'171 min': '< 200min' ,'48 min': '< 60min' ,'139 min': '< 200min' ,
            '157 min': '< 200min' ,'15 min': '< 60min' ,'161 min': '< 200min' ,'62 min': '< 100min' ,
            '39 min': '< 60min' ,'186 min': '< 200min' ,'73 min': '< 100min' ,'58 min': '< 60min' ,
            '65 min': '< 100min' ,'13 min': '< 60min' ,'165 min': '< 200min' ,'166 min': '< 200min' ,
            '138 min':'< 200min' ,'159 min': '< 200min' ,'141 min': '< 200min' ,'134 min': '< 200min' ,
            '182 min': '< 200min','132 min': '< 200min' ,'118 min': '< 200min' ,'76 min': '< 100min' ,
            '12 min': '< 60min' ,'67 min': '< 100min' ,'34 min': '< 60min' ,'312 min': '> 200min' ,
            '36 min': '< 100min' ,'155 min': '< 100min' ,'14 min': '< 100min' ,'128 min': '< 200min' ,
            '177 min': '< 200min' ,'11 min': '< 100min' ,'9 min': '< 100min' ,'46 min': '< 100min' ,
            '145 min': '< 200min' ,'66 min': '< 200min' ,'55 min': '< 60min' ,'47 min': '< 60min' ,
            '45 min': '< 60min' ,'8 min': '< 60min' ,'37 min': '< 60min' ,'181 min': '< 200min' ,
            '149 min': '< 200min' ,'50 min': '< 60min' ,'23 min': '< 60min' ,'185 min': '< 200min' ,
            '169 min': '< 200min' ,'27 min': '< 60min' ,'170 min': '< 200min' ,'153 min': '< 200min' ,
            '163 min': '< 200min' ,'33 min': '< 60min' ,'204 min': '> 200min' ,'32 min': '< 60min' ,
            '35 min': '< 60min' ,'179 min': '< 200min' ,'273 min': '> 200min' ,'193 min': '< 200min' ,
            '17 min': '< 60min' ,'192 min': '< 200min' ,'209 min': '> 200min' ,'187 min': '< 200min' ,
            '53 min': '< 60min' ,'224 min': '> 200min' ,'233 min': '> 200min' ,'152 min': '< 200min' ,
            '173 min': '< 200min' ,'19 min': '< 60min' ,'172 min': '< 200min' ,'208 min': '> 200min' ,
            '237 min': '> 200min' ,'31 min': '< 60min' ,'230 min': '> 200min' ,'194 min': '< 200min' ,
            '212 min': '> 200min' ,'3 min': '< 60min' ,'16 min': '< 60min' ,'5 min': '< 60min' ,
            '176 min': '< 200min' ,'195 min': '< 200min' ,'253 min': '> 200min' ,'41 min': '< 60min' ,
            '180 min': '< 200min' ,'190 min': '< 200min' ,'203 min': '> 200min' ,}

# %%
df_netflix.duration.replace(dic_time, inplace = True)

# %%
duration_netflix = df_netflix.loc[(df_netflix.duration !='no_value')]

# %%
#df_netflix duration repartition
sns.histplot(data=duration_netflix, y="duration")
# Out:
# <AxesSubplot: xlabel='Count', ylabel='duration'>
